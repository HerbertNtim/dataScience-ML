# %%
import numpy as np

# %%
# Creating Numpy Arrays
arr = np.array([1, 2, 3, 4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr3 = np.zeros((2, 3))

# %%
arr3
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [raw]
# arr4 = np.ones((2, 3))

# %% [raw]
# arr4
