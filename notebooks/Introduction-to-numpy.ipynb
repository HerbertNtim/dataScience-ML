# %%
import numpy as np

# %%
# Creating Numpy Arrays
arr = np.array([1, 2, 3, 4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
arr3 = np.zeros((2, 3))

# %%
arr3
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
arr4 = np.ones((2, 3))

# %%
arr4
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
#Pseudo-random numbers
# np.random.seed
random_array_4 = np.random.randint(10, size=(5, 3))
random_array_4
# Out:
# array([[0, 7, 7],
#        [3, 9, 6],
#        [2, 5, 3],
#        [5, 1, 1],
#        [3, 0, 1]], dtype=int32)

# %%
random_array_4.shape
# Out:
# (5, 3)

# %%
random_array_4.size
# Out:
# 15

# %%
np.random.seed(7)
random_array_5 = np.random.random((5, 3))
random_array_5
# Out:
# array([[0.07630829, 0.77991879, 0.43840923],
#        [0.72346518, 0.97798951, 0.53849587],
#        [0.50112046, 0.07205113, 0.26843898],
#        [0.4998825 , 0.67923   , 0.80373904],
#        [0.38094113, 0.06593635, 0.2881456 ]])

# %% [markdown]
# # Viewing array and Matrices

# %%
np.unique(random_array_4)
# Out:
# array([0, 1, 2, 3, 5, 6, 7, 9], dtype=int32)

# %%
arr_1d = np.array([10, 20, 30, 40, 50])

arr_1d
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
arr_2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_3d = np.array([[[1, 2], [4, 5]], [[5, 6], [7, 8]]])
arr_3d
# Out:
# array([[[1, 2],
#         [4, 5]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
arr_1d.ndim, arr_2d.ndim, arr_3d.ndim
# Out:
# (1, 2, 3)

# %%
arr_1d.size, arr_2d.size, arr_3d.size
# Out:
# (5, 6, 8)

# %%
arr_1d.dtype, arr_2d.dtype, arr_3d.dtype
# Out:
# (dtype('int64'), dtype('int64'), dtype('int64'))

# %%
arr_1d.itemsize, arr_2d.itemsize, arr_3d.itemsize
# Out:
# (8, 8, 8)

# %%
arr_1d.nbytes, arr_2d.nbytes, arr_3d.nbytes
# Out:
# (40, 48, 64)

# %%
arr_1d[0], arr_1d[2], arr_1d[-1]
# Out:
# (np.int64(10), np.int64(30), np.int64(50))

# %%
arr_1d
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr_1d[1:4], arr_1d[:3], arr_1d[::2]
# Out:
# (array([20, 30, 40]), array([10, 20, 30]), array([10, 30, 50]))

# %%
arr_2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_2d[0, 1], arr_2d[1,0]
# Out:
# (np.int64(2), np.int64(4))

# %%
arr_2d[0, :], arr_2d[:, 1]
# Out:
# (array([1, 2, 3]), array([2, 5]))

# %% [markdown]
# ## 4. Manipulating & Comparing Arrays

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
a + b
# Out:
# array([5, 7, 9])

# %%
b - a
# Out:
# array([3, 3, 3])

# %%
b/a
# Out:
# array([4. , 2.5, 2. ])

# %%
a ** 2
# Out:
# array([1, 4, 9])

# %%
b % a
# Out:
# array([0, 1, 0])

# %% [markdown]
# ## 5. Aggregations

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
np.sum(arr), np.mean(arr), np.median(arr), np.min(arr), np.max(arr), np.std(arr), np.var(arr)
# Out:
# (np.int64(15),
#  np.float64(3.0),
#  np.float64(3.0),
#  np.int64(1),
#  np.int64(5),
#  np.float64(1.4142135623730951),
#  np.float64(2.0))
